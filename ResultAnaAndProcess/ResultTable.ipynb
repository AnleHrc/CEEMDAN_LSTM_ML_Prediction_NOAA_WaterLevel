# %%
import pandas as pd
import os
import glob

# %%
csv_path = '../Data/PreData/ArtiData'
csv_files = glob.glob(os.path.join(csv_path,'*.csv'))

sites_names=[]

for file in csv_files:
 file_name = os.path.basename(file)
 first_underscore_index = file_name.find("_")
 second_underscore_index = file_name.find("_", first_underscore_index + 1)
 site_name = file_name[first_underscore_index + 1:second_underscore_index]
 print('For '+site_name)
 sites_names.append(site_name)
 print("-------------------------")
# Out:
# For AU-ASM
# -------------------------
# For AU-Emr
# -------------------------
# For BE-Lon
# -------------------------
# For BE-Vie
# -------------------------
# For DE-Lnf
# -------------------------
# For DE-Seh
# -------------------------
# For FI-Jok
# -------------------------
# For FI-Let
# -------------------------
# For JP-MBF
# -------------------------
# For JP-SMF
# -------------------------
# For US-Goo
# -------------------------
# For US-Oho
# -------------------------

# %%
df = pd.read_csv('Result.csv')
df
# Out:
#       Site    Statistical metrics        R²(%)   Unnamed: 3   Unnamed: 4  \
# 0      NaN  Model/Input component           C1           C2           C3
# 1   AU-ASM               LightGBM   0.94815512  0.948128994  0.951365172
# 2      NaN                 BiLSTM  0.949284078  0.956818367  0.955050122
# 3      NaN              StackLSTM  0.946577172  0.948390528  0.952182939
# 4      NaN                   LSTM  0.937110754  0.950128238  0.959117364
# 5      NaN                     RF  0.947453024  0.950927093  0.953296869
# 6      NaN                    SVM  0.903029575  0.914437724  0.916004858
# 7      NaN                    XGB  0.944073949  0.949126087  0.952112303
# 8   AU-Emr               LightGBM  0.931235443  0.929377326  0.921789671
# 9      NaN                 BiLSTM  0.925047064  0.936382798  0.929418715
# 10     NaN              StackLSTM  0.930017258  0.934437612  0.932936574
# 11     NaN                   LSTM  0.933408213  0.936708576  0.910633221
# ...

# %%
csv_path = '../Data/PreData/ArtiData'
csv_files = glob.glob(os.path.join(csv_path,'*.csv'))

sites_names=[]

for file in csv_files:
 file_name = os.path.basename(file)
 first_underscore_index = file_name.find("_")
 second_underscore_index = file_name.find("_", first_underscore_index + 1)
 site_name = file_name[first_underscore_index + 1:second_underscore_index]
 print('For '+site_name)
 sites_names.append(site_name)
 print("-------------------------")
# Out:
# For AU-ASM
# -------------------------
# For AU-Emr
# -------------------------
# For BE-Lon
# -------------------------
# For BE-Vie
# -------------------------
# For DE-Lnf
# -------------------------
# For DE-Seh
# -------------------------
# For FI-Jok
# -------------------------
# For FI-Let
# -------------------------
# For JP-MBF
# -------------------------
# For JP-SMF
# -------------------------
# For US-Goo
# -------------------------
# For US-Oho
# -------------------------

# %%
csv_path = '../Data/PreData/ArtiData'
csv_files = glob.glob(os.path.join(csv_path,'*.csv'))

sites_names=[]
origin_path = 'Result.csv'
origin_file = pd.read_csv(origin_path)
for file in csv_files:
 file_name = os.path.basename(file)
 first_underscore_index = file_name.find("_")
 second_underscore_index = file_name.find("_", first_underscore_index + 1)
 site_name = file_name[first_underscore_index + 1:second_underscore_index]
 print('For '+site_name)
 sites_names.append(site_name)
 print("****************************")

 empty_rows = origin_file.isnull().all(axis=1)
 # 查找第一个没有数据的行的索引
 first_empty_row_index = empty_rows.idxmax()
 # 在第一个没有数据的行的第一列插入'ABC'
 origin_file.loc[len(empty_rows), origin_file.columns[0]] = site_name
 model = ['LightGBM','BiLSTM','StackLSTM','LSTM','RF','SVM','XGB']
 for i in range(7):
  origin_file.loc[len(empty_rows)+i,origin_file.columns[1]] = model[i]
 csv_path = '../ResultAnaAndProcess/FinalResult_Eva/'
 sub_file = next(os.walk(csv_path))[1]

 for c_result in sub_file: #
  print('---------------------------')
  print(csv_path+c_result+'/{}'.format(site_name)+'.csv')
  df = pd.read_csv(csv_path+c_result+'/{}'.format(site_name)+'.csv')

  origin_eva_index_seq = []
  if c_result == 'All_Features':
   cols_name = 'C6'
   origin_eva_index_seq = [25,25-6*2,25-6*1,25-6*3]
  if c_result == 'SW__LW':
   cols_name = 'C2'
   origin_eva_index_seq = [21,21-6*2,21-6*1,21-6*3]
  if c_result == 'SW__PA':
   cols_name = 'C4'
   origin_eva_index_seq = [23,23-6*2,23-6*1,23-6*3]
  if c_result == 'SW__TA':
   cols_name = 'C1'
   origin_eva_index_seq = [20,20-6*2,20-6*1,20-6*3]
  if c_result == 'SW__VPD':
   cols_name = 'C3'
   origin_eva_index_seq = [22,22-6*2,22-6*1,22-6*3]
  if c_result == 'SW__WS':
   cols_name = 'C5'
   origin_eva_index_seq = [24,24-6*2,24-6*1,24-6*3]
  print('c_result',c_result)
  for i in range(len(df.iloc[:,0])):
   for j in range(len(df.iloc[i,1:].values)):
    origin_file.loc[len(empty_rows)+j,origin_file.columns[origin_eva_index_seq[i]]] = df.iloc[i,1:].values[j]
  print('---------------------------')
  print(df)
 print('****************************')
  # df = pd.read_csv(csv_path+sub_file[1][0]+'/'+'AU-ASM.csv')
# Out:
# For AU-ASM
# ****************************
# ---------------------------
# ../ResultAnaAndProcess/FinalResult_Eva/All_Features/AU-ASM.csv
# c_result All_Features
# ---------------------------
#    Index  LightGBM    BiLSTM  StackLSTM       LSTM        RF       SVM  \
# 0    MAE  2.487799  2.417900    2.836876  2.593864  2.838140  4.805898
# 1   RMSE  4.719004  4.413354    4.681237  4.648843  4.761881  6.029171
# 2  nRMSE  0.070180  0.065635    0.069618  0.069137  0.070818  0.089665
# 3     R2  0.950898  0.958372    0.949147  0.954521  0.952828  0.896974
#
#         XGB
# 0  2.884249
# 1  4.629753
# 2  0.068853
# 3  0.955151
# ---------------------------
# ../ResultAnaAndProcess/FinalResult_Eva/SW__LW/AU-ASM.csv
# c_result SW__LW
# ---------------------------
#    Index  LightGBM    BiLSTM  StackLSTM       LSTM        RF       SVM  \
# 0    MAE  2.490830  2.369865    2.775965  3.031414  2.878563  4.342258
# 1   RMSE  4.865996  4.456599    4.756618  4.938696  4.900186  5.636641
# ...

# %%
origin_file.to_csv('python_contact_result.csv',index=False)

# %%
df
# Out:
#    Index  LightGBM    BiLSTM  StackLSTM       LSTM        RF       SVM  \
# 0    MAE  3.432164  3.364162    3.162952  3.373532  3.376755  4.053101
# 1   RMSE  4.830581  4.765093    4.600805  4.795467  4.907420  5.186416
# 2  nRMSE  0.100219  0.098861    0.095452  0.099491  0.101814  0.107602
# 3     R2  0.859754  0.874504    0.875162  0.862042  0.868291  0.804798
#
#         XGB
# 0  3.649883
# 1  5.108087
# 2  0.105977
# 3  0.852965

# %%
df = pd.read_csv('Result.csv')
empty_rows = df.isnull().all(axis=1)
# 查找第一个没有数据的行的索引
first_empty_row_index = empty_rows.idxmax()
# 在第一个没有数据的行的第一列插入'ABC'
df.loc[len(empty_rows), df.columns[0]] = site_name
A = ['A','B','C','D','E','F','G']
for i in range(7):
 df.loc[len(empty_rows)+i,df.columns[1]] = A[i]

# %%
df
# Out:
#       Site    Statistical metrics        R²(%)   Unnamed: 3   Unnamed: 4  \
# 0      NaN  Model/Input component           C1           C2           C3
# 1   AU-ASM               LightGBM   0.94815512  0.948128994  0.951365172
# 2      NaN                 BiLSTM  0.949284078  0.956818367  0.955050122
# 3      NaN              StackLSTM  0.946577172  0.948390528  0.952182939
# 4      NaN                   LSTM  0.937110754  0.950128238  0.959117364
# 5      NaN                     RF  0.947453024  0.950927093  0.953296869
# 6      NaN                    SVM  0.903029575  0.914437724  0.916004858
# 7      NaN                    XGB  0.944073949  0.949126087  0.952112303
# 8   AU-Emr               LightGBM  0.931235443  0.929377326  0.921789671
# 9      NaN                 BiLSTM  0.925047064  0.936382798  0.929418715
# 10     NaN              StackLSTM  0.930017258  0.934437612  0.932936574
# 11     NaN                   LSTM  0.933408213  0.936708576  0.910633221
# ...

# %%
len(df.iloc[:,0])
# Out:
# 35

# %%
empty_rows = df.isnull().all(axis=1)
# 查找第一个没有数据的行的索引
first_empty_row_index = empty_rows.idxmax()
# 在第一个没有数据的行的第一列插入'ABC'
df.loc[len(empty_rows), df.columns[0]] = 'ABC'
# Out:
# 0

# %%
df
# Out:
#       Site    Statistical metrics        R²(%)   Unnamed: 3   Unnamed: 4  \
# 0      NaN  Model/Input component           C1           C2           C3
# 1   AU-ASM               LightGBM   0.94815512  0.948128994  0.951365172
# 2      NaN                 BiLSTM  0.949284078  0.956818367  0.955050122
# 3      NaN              StackLSTM  0.946577172  0.948390528  0.952182939
# 4      NaN                   LSTM  0.937110754  0.950128238  0.959117364
# 5      NaN                     RF  0.947453024  0.950927093  0.953296869
# 6      NaN                    SVM  0.903029575  0.914437724  0.916004858
# 7      NaN                    XGB  0.944073949  0.949126087  0.952112303
# 8   AU-Emr               LightGBM  0.931235443  0.929377326  0.921789671
# 9      NaN                 BiLSTM  0.925047064  0.936382798  0.929418715
# 10     NaN              StackLSTM  0.930017258  0.934437612  0.932936574
# 11     NaN                   LSTM  0.933408213  0.936708576  0.910633221
# ...
