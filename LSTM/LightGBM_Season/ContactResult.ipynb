# %%
import pandas as pd
import os

# 创建一个空的数据框来存储合并后的数据
merged_data = pd.DataFrame()

# 指定文件夹路径
folder_path = '../LightGBM_Season/'  # 将 "your_folder_path" 替换为包含这些文件的文件夹的实际路径

# 遍历文件夹中的每个文件
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):  # 确保只处理 CSV 文件
        file_path = os.path.join(folder_path, filename)
        print(file_path)
        # 读取 CSV 文件
        data = pd.read_csv(file_path)
        print(data)
        # 从文件名中提取站点名和月份
        print(filename.split(".")[0].split("_"))
        print(filename.split("cs")[2].split('.')[0])
        station_name = filename.split(".")[0].split("_")[0]
        month = filename.split("cs")[2].split('.')[0]
        data["Station"] = station_name
        data["Month"] = month

        # 合并数据到总数据框
        merged_data = pd.concat([merged_data, data])
# 打印合并后的数据
print(merged_data)
# 保存合并后的数据到新的 CSV 文件
output_path = "merged_data.csv"  # 指定输出文件的路径和文件名
merged_data.to_csv(output_path, index=False)
# Out:
# ../LightGBM_Season/Burlington Station.cs_metrics_12.csv
#   Metric     Value
# 0     R2  0.756227
# 1   RMSE  0.384507
# 2    MAE  0.337214
# ['Burlington Station']
# _12
# ../LightGBM_Season/Burlington Station.cs_metrics_3.csv
#   Metric     Value
# 0     R2  0.756742
# 1   RMSE  0.391845
# 2    MAE  0.351276
# ['Burlington Station']
# _3
# ../LightGBM_Season/Burlington Station.cs_metrics_6.csv
#   Metric     Value
# 0     R2  0.742975
# 1   RMSE  0.409151
# 2    MAE  0.365206
# ['Burlington Station']
# _6
# ../LightGBM_Season/Burlington Station.cs_metrics_9.csv
#   Metric     Value
# 0     R2  0.735905
# 1   RMSE  0.403066
# 2    MAE  0.356053
# ['Burlington Station']
# _9
# ../LightGBM_Season/HONOLULU Station.cs_metrics_12.csv
#   Metric     Value
# 0     R2  0.864827
# 1   RMSE  0.074139
# 2    MAE  0.060163
# ['HONOLULU Station']
# _12
# ../LightGBM_Season/HONOLULU Station.cs_metrics_3.csv
#   Metric     Value
# 0     R2  0.819427
# 1   RMSE  0.069930
# 2    MAE  0.057747
# ['HONOLULU Station']
# _3
# ../LightGBM_Season/HONOLULU Station.cs_metrics_6.csv
#   Metric     Value
# 0     R2  0.866705
# 1   RMSE  0.070209
# 2    MAE  0.056605
# ['HONOLULU Station']
# _6
# ../LightGBM_Season/HONOLULU Station.cs_metrics_9.csv
#   Metric     Value
# 0     R2  0.828140
# 1   RMSE  0.070885
# 2    MAE  0.057749
# ['HONOLULU Station']
# _9
# ../LightGBM_Season/KAHUKUI Station.cs_metrics_12.csv
#   Metric     Value
# 0     R2  0.841127
# 1   RMSE  0.092229
# 2    MAE  0.073402
# ['KAHUKUI Station']
# _12
# ../LightGBM_Season/KAHUKUI Station.cs_metrics_3.csv
#   Metric     Value
# 0     R2  0.776138
# 1   RMSE  0.097503
# 2    MAE  0.080328
# ['KAHUKUI Station']
# _3
# ../LightGBM_Season/KAHUKUI Station.cs_metrics_6.csv
#   Metric     Value
# 0     R2  0.855133
# 1   RMSE  0.088846
# 2    MAE  0.072351
# ['KAHUKUI Station']
# _6
# ../LightGBM_Season/KAHUKUI Station.cs_metrics_9.csv
#   Metric     Value
# 0     R2  0.784456
# 1   RMSE  0.095730
# 2    MAE  0.077561
# ['KAHUKUI Station']
# _9
# ../LightGBM_Season/LaJolla Station.cs_metrics_12.csv
#   Metric     Value
# 0     R2  0.840129
# 1   RMSE  0.207303
# 2    MAE  0.173911
# ['LaJolla Station']
# _12
# ../LightGBM_Season/LaJolla Station.cs_metrics_3.csv
#   Metric     Value
# 0     R2  0.809404
# 1   RMSE  0.214370
# 2    MAE  0.179251
# ['LaJolla Station']
# _3
# ../LightGBM_Season/LaJolla Station.cs_metrics_6.csv
#   Metric     Value
# 0     R2  0.828876
# 1   RMSE  0.212314
# 2    MAE  0.173558
# ['LaJolla Station']
# _6
# ../LightGBM_Season/LaJolla Station.cs_metrics_9.csv
#   Metric     Value
# 0     R2  0.788158
# 1   RMSE  0.220256
# 2    MAE  0.178881
# ['LaJolla Station']
# _9
# ../LightGBM_Season/Nawiliwili Station.cs_metrics_12.csv
#   Metric     Value
# 0     R2  0.870244
# 1   RMSE  0.070877
# 2    MAE  0.058251
# ['Nawiliwili Station']
# _12
# ../LightGBM_Season/Nawiliwili Station.cs_metrics_3.csv
#   Metric     Value
# 0     R2  0.823113
# 1   RMSE  0.070374
# 2    MAE  0.058068
# ['Nawiliwili Station']
# _3
# ../LightGBM_Season/Nawiliwili Station.cs_metrics_6.csv
#   Metric     Value
# 0     R2  0.875249
# 1   RMSE  0.070253
# 2    MAE  0.057170
# ['Nawiliwili Station']
# _6
# ../LightGBM_Season/Nawiliwili Station.cs_metrics_9.csv
#   Metric     Value
# 0     R2  0.817800
# 1   RMSE  0.073819
# 2    MAE  0.060076
# ['Nawiliwili Station']
# _9
#   Metric     Value             Station Month
# 0     R2  0.756227  Burlington Station   _12
# 1   RMSE  0.384507  Burlington Station   _12
# 2    MAE  0.337214  Burlington Station   _12
# 0     R2  0.756742  Burlington Station    _3
# 1   RMSE  0.391845  Burlington Station    _3
# 2    MAE  0.351276  Burlington Station    _3
# 0     R2  0.742975  Burlington Station    _6
# 1   RMSE  0.409151  Burlington Station    _6
# 2    MAE  0.365206  Burlington Station    _6
# 0     R2  0.735905  Burlington Station    _9
# 1   RMSE  0.403066  Burlington Station    _9
# 2    MAE  0.356053  Burlington Station    _9
# 0     R2  0.864827    HONOLULU Station   _12
# 1   RMSE  0.074139    HONOLULU Station   _12
# 2    MAE  0.060163    HONOLULU Station   _12
# 0     R2  0.819427    HONOLULU Station    _3
# 1   RMSE  0.069930    HONOLULU Station    _3
# 2    MAE  0.057747    HONOLULU Station    _3
# 0     R2  0.866705    HONOLULU Station    _6
# 1   RMSE  0.070209    HONOLULU Station    _6
# 2    MAE  0.056605    HONOLULU Station    _6
# 0     R2  0.828140    HONOLULU Station    _9
# 1   RMSE  0.070885    HONOLULU Station    _9
# 2    MAE  0.057749    HONOLULU Station    _9
# 0     R2  0.841127     KAHUKUI Station   _12
# 1   RMSE  0.092229     KAHUKUI Station   _12
# 2    MAE  0.073402     KAHUKUI Station   _12
# 0     R2  0.776138     KAHUKUI Station    _3
# 1   RMSE  0.097503     KAHUKUI Station    _3
# 2    MAE  0.080328     KAHUKUI Station    _3
# 0     R2  0.855133     KAHUKUI Station    _6
# 1   RMSE  0.088846     KAHUKUI Station    _6
# 2    MAE  0.072351     KAHUKUI Station    _6
# 0     R2  0.784456     KAHUKUI Station    _9
# 1   RMSE  0.095730     KAHUKUI Station    _9
# 2    MAE  0.077561     KAHUKUI Station    _9
# 0     R2  0.840129     LaJolla Station   _12
# 1   RMSE  0.207303     LaJolla Station   _12
# 2    MAE  0.173911     LaJolla Station   _12
# 0     R2  0.809404     LaJolla Station    _3
# 1   RMSE  0.214370     LaJolla Station    _3
# 2    MAE  0.179251     LaJolla Station    _3
# 0     R2  0.828876     LaJolla Station    _6
# 1   RMSE  0.212314     LaJolla Station    _6
# 2    MAE  0.173558     LaJolla Station    _6
# 0     R2  0.788158     LaJolla Station    _9
# 1   RMSE  0.220256     LaJolla Station    _9
# 2    MAE  0.178881     LaJolla Station    _9
# 0     R2  0.870244  Nawiliwili Station   _12
# 1   RMSE  0.070877  Nawiliwili Station   _12
# 2    MAE  0.058251  Nawiliwili Station   _12
# 0     R2  0.823113  Nawiliwili Station    _3
# 1   RMSE  0.070374  Nawiliwili Station    _3
# 2    MAE  0.058068  Nawiliwili Station    _3
# 0     R2  0.875249  Nawiliwili Station    _6
# 1   RMSE  0.070253  Nawiliwili Station    _6
# 2    MAE  0.057170  Nawiliwili Station    _6
# 0     R2  0.817800  Nawiliwili Station    _9
# 1   RMSE  0.073819  Nawiliwili Station    _9
# 2    MAE  0.060076  Nawiliwili Station    _9
