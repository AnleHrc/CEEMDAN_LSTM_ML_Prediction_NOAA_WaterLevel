# %%
import pandas as pd
import os

# 创建一个空的数据框来存储合并后的数据
merged_data = pd.DataFrame()

# 指定文件夹路径
folder_path = '../RF/'  # 将 "your_folder_path" 替换为包含这些文件的文件夹的实际路径

# 遍历文件夹中的每个文件
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):  # 确保只处理 CSV 文件
        file_path = os.path.join(folder_path, filename)
        print(file_path)
        # 读取 CSV 文件
        data = pd.read_csv(file_path)
        print(data)
        # 从文件名中提取站点名和月份
        print(filename.split(".")[0].split("_"))
        print(filename.split("cs")[2].split('.')[0])
        station_name = filename.split(".")[0].split("_")[0]
        month = filename.split("cs")[2].split('.')[0]
        data["Station"] = station_name
        data["Month"] = month

        # 合并数据到总数据框
        merged_data = pd.concat([merged_data, data])
# 打印合并后的数据
print(merged_data)
# 保存合并后的数据到新的 CSV 文件
output_path = "merged_data.csv"  # 指定输出文件的路径和文件名
merged_data.to_csv(output_path, index=False)
# Out:
# ../RF/Burlington Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.768775
# 1   RMSE  0.374732
# 2    MAE  0.336646
# ['Burlington Station']
# 12
# ../RF/Burlington Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.767020
# 1   RMSE  0.383509
# 2    MAE  0.348677
# ['Burlington Station']
# 3
# ../RF/Burlington Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.756743
# 1   RMSE  0.398056
# 2    MAE  0.359632
# ['Burlington Station']
# 6
# ../RF/Burlington Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.751602
# 1   RMSE  0.390687
# 2    MAE  0.352160
# ['Burlington Station']
# 9
# ../RF/HONOLULU Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.872850
# 1   RMSE  0.071947
# 2    MAE  0.058843
# ['HONOLULU Station']
# 12
# ../RF/HONOLULU Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.820269
# 1   RMSE  0.069788
# 2    MAE  0.057157
# ['HONOLULU Station']
# 3
# ../RF/HONOLULU Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.867232
# 1   RMSE  0.070108
# 2    MAE  0.056399
# ['HONOLULU Station']
# 6
# ../RF/HONOLULU Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.826335
# 1   RMSE  0.071240
# 2    MAE  0.058066
# ['HONOLULU Station']
# 9
# ../RF/KAHUKUI Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.853377
# 1   RMSE  0.088617
# 2    MAE  0.070931
# ['KAHUKUI Station']
# 12
# ../RF/KAHUKUI Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.805532
# 1   RMSE  0.090709
# 2    MAE  0.076369
# ['KAHUKUI Station']
# 3
# ../RF/KAHUKUI Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.857970
# 1   RMSE  0.088026
# 2    MAE  0.071168
# ['KAHUKUI Station']
# 6
# ../RF/KAHUKUI Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.802910
# 1   RMSE  0.091478
# 2    MAE  0.075491
# ['KAHUKUI Station']
# 9
# ../RF/LaJolla Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.845148
# 1   RMSE  0.204072
# 2    MAE  0.172277
# ['LaJolla Station']
# 12
# ../RF/LaJolla Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.811873
# 1   RMSE  0.213102
# 2    MAE  0.178293
# ['LaJolla Station']
# 3
# ../RF/LaJolla Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.840224
# 1   RMSE  0.205103
# 2    MAE  0.168924
# ['LaJolla Station']
# 6
# ../RF/LaJolla Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.806186
# 1   RMSE  0.210784
# 2    MAE  0.175319
# ['LaJolla Station']
# 9
# ../RF/Nawiliwili Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.881538
# 1   RMSE  0.067760
# 2    MAE  0.055585
# ['Nawiliwili Station']
# 12
# ../RF/Nawiliwili Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.832841
# 1   RMSE  0.068430
# 2    MAE  0.056706
# ['Nawiliwili Station']
# 3
# ../RF/Nawiliwili Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.869166
# 1   RMSE  0.071968
# 2    MAE  0.058701
# ['Nawiliwili Station']
# 6
# ../RF/Nawiliwili Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.825161
# 1   RMSE  0.072221
# 2    MAE  0.059436
# ['Nawiliwili Station']
# 9
#   Metric     Value             Station Month
# 0     R2  0.768775  Burlington Station    12
# 1   RMSE  0.374732  Burlington Station    12
# 2    MAE  0.336646  Burlington Station    12
# 0     R2  0.767020  Burlington Station     3
# 1   RMSE  0.383509  Burlington Station     3
# 2    MAE  0.348677  Burlington Station     3
# 0     R2  0.756743  Burlington Station     6
# 1   RMSE  0.398056  Burlington Station     6
# 2    MAE  0.359632  Burlington Station     6
# 0     R2  0.751602  Burlington Station     9
# 1   RMSE  0.390687  Burlington Station     9
# 2    MAE  0.352160  Burlington Station     9
# 0     R2  0.872850    HONOLULU Station    12
# 1   RMSE  0.071947    HONOLULU Station    12
# 2    MAE  0.058843    HONOLULU Station    12
# 0     R2  0.820269    HONOLULU Station     3
# 1   RMSE  0.069788    HONOLULU Station     3
# 2    MAE  0.057157    HONOLULU Station     3
# 0     R2  0.867232    HONOLULU Station     6
# 1   RMSE  0.070108    HONOLULU Station     6
# 2    MAE  0.056399    HONOLULU Station     6
# 0     R2  0.826335    HONOLULU Station     9
# 1   RMSE  0.071240    HONOLULU Station     9
# 2    MAE  0.058066    HONOLULU Station     9
# 0     R2  0.853377     KAHUKUI Station    12
# 1   RMSE  0.088617     KAHUKUI Station    12
# 2    MAE  0.070931     KAHUKUI Station    12
# 0     R2  0.805532     KAHUKUI Station     3
# 1   RMSE  0.090709     KAHUKUI Station     3
# 2    MAE  0.076369     KAHUKUI Station     3
# 0     R2  0.857970     KAHUKUI Station     6
# 1   RMSE  0.088026     KAHUKUI Station     6
# 2    MAE  0.071168     KAHUKUI Station     6
# 0     R2  0.802910     KAHUKUI Station     9
# 1   RMSE  0.091478     KAHUKUI Station     9
# 2    MAE  0.075491     KAHUKUI Station     9
# 0     R2  0.845148     LaJolla Station    12
# 1   RMSE  0.204072     LaJolla Station    12
# 2    MAE  0.172277     LaJolla Station    12
# 0     R2  0.811873     LaJolla Station     3
# 1   RMSE  0.213102     LaJolla Station     3
# 2    MAE  0.178293     LaJolla Station     3
# 0     R2  0.840224     LaJolla Station     6
# 1   RMSE  0.205103     LaJolla Station     6
# 2    MAE  0.168924     LaJolla Station     6
# 0     R2  0.806186     LaJolla Station     9
# 1   RMSE  0.210784     LaJolla Station     9
# 2    MAE  0.175319     LaJolla Station     9
# 0     R2  0.881538  Nawiliwili Station    12
# 1   RMSE  0.067760  Nawiliwili Station    12
# 2    MAE  0.055585  Nawiliwili Station    12
# 0     R2  0.832841  Nawiliwili Station     3
# 1   RMSE  0.068430  Nawiliwili Station     3
# 2    MAE  0.056706  Nawiliwili Station     3
# 0     R2  0.869166  Nawiliwili Station     6
# 1   RMSE  0.071968  Nawiliwili Station     6
# 2    MAE  0.058701  Nawiliwili Station     6
# 0     R2  0.825161  Nawiliwili Station     9
# 1   RMSE  0.072221  Nawiliwili Station     9
# 2    MAE  0.059436  Nawiliwili Station     9
