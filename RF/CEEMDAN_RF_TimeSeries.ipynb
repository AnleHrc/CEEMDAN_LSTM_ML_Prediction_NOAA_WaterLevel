# %%
import os
import glob
import matplotlib
import numpy as np
import pandas as pd
import warnings
import math
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score as r2, mean_squared_error
# 忽略警告
warnings.filterwarnings("ignore", category=matplotlib.MatplotlibDeprecationWarning)
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score as r2

# %%
# import os
# import glob
#
# csv_path = '../../Data/PreData/ArtiData'
# csv_files = glob.glob(os.path.join(csv_path, '*.csv'))
#
# start_index = 10  # 起始索引，即第4个文件
# end_index = 12  # 结束索引，即第6个文件（不包括第7个文件）
#
# for index, file in enumerate(csv_files[start_index:end_index]):
#     # LSTM_ALL(os.path.basename(file))
#     print(os.path.basename(file))
#     print("-------------------------")

IMF = []
xlsx_file = '../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI/'
xlsx_path = glob.glob(os.path.join(xlsx_file,'*.xlsx'))

data_col_len = pd.read_excel('../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI/CEEMDAN_KAHUKUI Station_WL.xlsx')

for imf_len in range(len(data_col_len.columns)):
    for file in xlsx_path:
         print(file)
         # print(os.path.basename(file))
         imfs = pd.read_excel(file)
         imfn = imfs.iloc[:,imf_len]
         imfn.to_numpy()
         IMF.append(imfn)
    print(imf_len,"-------------------")
# Out:
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 0 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 1 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 2 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 3 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 4 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 5 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 6 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 7 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 8 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 9 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 10 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 11 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 12 -------------------
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_AT.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_Baro.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WD.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WG.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WL.xlsx
# ../LSTM/TensorFlow_LSTM/CEEMDAN_Data/KAHUKUI\CEEMDAN_KAHUKUI Station_WS.xlsx
# 13 -------------------

# %%
# %%time
import tensorflow as tf

# Check if GPU is available and set the GPU device
if tf.test.is_gpu_available():
    physical_devices = tf.config.list_physical_devices('GPU')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
imf_choose = 0
finally_rsult = []
finally_y_true = []
#int(len(IMF)/6)
for imf_run in range(int(len(IMF) / 6)):
    ALL_Factor_IMF = IMF[imf_choose:imf_choose+6][:]
    imf_choose = imf_choose + 6
    # imf_choose = imf_choose + 6
    print('--------------------------',imf_run,'--------------------------')
    # IMF[imf_run] = ALL_Factor_IMF
    # print("ALL_Factor_IMF:",ALL_Factor_IMF)
    ALL_Factor_IMF = np.array(ALL_Factor_IMF)
    IMF_Input = np.transpose(ALL_Factor_IMF)
    # print(IMF_Input)

    #[AT,Baro,WD,WG,WL,WS]
    IMF_Input
    df_IMF = pd.DataFrame(IMF_Input)
    # df_IMF.columns = ['AT','Baro','WD','WG','WL','WS']
    df_IMF.columns = ['AT','Baro','WD','WG','WL','WS']
    df_IMF = df_IMF[['WS','WL','WG','AT','Baro','WL']]
    # print(df_IMF)

    # 数据范围过大，对数据进行归一化
    scaler = MinMaxScaler(feature_range=(0, 1))
    df = scaler.fit_transform(df_IMF)

    #数据集划分
    test_split = round(len(df) * 0.20)
    print(test_split)
    def splitData(var, per_test):
        num_test = int(len(var) * per_test)
        train_size = int(len(var) - num_test)
        train_data = var[0:train_size]
        test_data = var[train_size:train_size + num_test]
        return train_data, test_data
    df_training, df_testing = splitData(df, 0.2)
    print(df_training.shape)
    print(df_testing.shape)

    def createXY(dataset, n_past):
        data_X = []
        data_Y = []
        for i in range(n_past, len(dataset)):
            data_X.append(dataset[i - n_past:i, 0:dataset.shape[1]])
            data_Y.append(dataset[i, 5])

        return np.array(data_X), np.array(data_Y)


    trainX, trainY = createXY(df_training, 1)
    testX, testY = createXY(df_testing, 1)

    print('trainX.Shape:----', trainX.shape)
    print('trainY.shape:----', trainY.shape)
    print('testX.shape:----', testX.shape)
    print('testY.shape:----', testY.shape)
    print('----------------------------',imf_run,'------------------------------')

    trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1] * trainX.shape[2]))


    testX = np.reshape(testX, (testX.shape[0], testX.shape[1] * testX.shape[2]))

    from sklearn.ensemble import RandomForestRegressor

    model = RandomForestRegressor(n_estimators=42, oob_score=True, n_jobs=-1, random_state=37, max_features=1.0,
                                  min_samples_leaf=2)
    # from sklearn.svm import SVR
    # svr = SVR(kernel='rbf')
    # model = svr.fit(trainX, trainY)
    model.fit(trainX, trainY)
    # %%
    pre = model.predict(testX)

    pre = np.array(pre).reshape(-1, 1)

    prediction_copies_array = np.repeat(pre, trainX.shape[1], axis=-1)  # 将一个数组prediction在最后一个轴上（即axis=-1）进行复制，重复8次，并将

    pre = scaler.inverse_transform(np.reshape(prediction_copies_array, (len(pre), trainX.shape[1])))[:,
          5]  # 进行逆变换但是，只需要最后一列

    test_data = np.array(testY).reshape(-1, 1)

    prediction_copies_test_data = np.repeat(test_data, trainX.shape[1],
                                            axis=-1)  # 将一个数组prediction在最后一个轴上（即axis=-1）进行复制，重复8次，并将
    prediction_copies_test_data
    test_data = scaler.inverse_transform(np.reshape(prediction_copies_test_data, (len(test_data), trainX.shape[1])))[:,
                5]  # 进行逆变换但是，只需要最后一列

    y = np.array(test_data)
    y_pred = pre
    finally_rsult.append(y_pred)
    finally_y_true.append(y)
    MSE = mean_squared_error(y, y_pred)
    RMSE = math.sqrt(MSE)
    # MAE=mean_absolute_error(y, pre)
    # MAPE = metrics.mean_absolute_percentage_error(y, pre)
    MAE = np.mean(np.abs(y - y_pred))
    # MAPE = np.mean(np.abs((y - y_pred) / y))
    print("rmse :", RMSE)
    print("mae :", MAE)
    # print("mape :", MAPE)
    print('R² :', r2(y, y_pred))
    plt.plot(y, color='red', label='Real Value')
    plt.plot(y_pred, color='blue', label='Pred Value')
    plt.title('Prediction Water Level')
    plt.xlabel('Time')
    plt.ylabel('Detail Value')
    plt.legend()
    plt.show()
# Out:
# -------------------------- 0 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 0 ------------------------------
# rmse : 0.02205788607431277
# mae : 0.016936608056794165
# R² : -0.02017859347450468
# -------------------------- 1 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 1 ------------------------------
# rmse : 0.0031371889563828847
# mae : 0.002390903784074945
# R² : 0.23328076463421898
# -------------------------- 2 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 2 ------------------------------
# rmse : 0.04288918742390385
# mae : 0.033188158942117796
# R² : 0.7306320461030038
# -------------------------- 3 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 3 ------------------------------
# rmse : 0.041137167832163084
# mae : 0.03278696417226478
# R² : 0.8897733345164145
# -------------------------- 4 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 4 ------------------------------
# rmse : 0.024923698278003524
# mae : 0.020868053382122925
# R² : 0.9016311843137971
# -------------------------- 5 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 5 ------------------------------
# rmse : 0.001349716098848847
# mae : 0.0010408126112725104
# R² : 0.9738608725415256
# -------------------------- 6 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 6 ------------------------------
# rmse : 0.0033388775214083675
# mae : 0.0013091052020064952
# R² : 0.911729241454366
# -------------------------- 7 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 7 ------------------------------
# rmse : 0.0003931961612844937
# mae : 0.0003116642412423714
# R² : 0.9973804483900265
# -------------------------- 8 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 8 ------------------------------
# rmse : 0.0010856232241643706
# mae : 0.00044012139508851754
# R² : 0.9927411769483921
# -------------------------- 9 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 9 ------------------------------
# rmse : 0.00010536945819417817
# mae : 8.600169308654515e-05
# R² : 0.9997882262849611
# -------------------------- 10 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 10 ------------------------------
# rmse : 0.00018260374101725349
# mae : 8.981562024340712e-05
# R² : 0.9996312502636816
# -------------------------- 11 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 11 ------------------------------
# rmse : 0.00771509085816265
# mae : 0.005074525410912917
# R² : 0.7819110168366588
# -------------------------- 12 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 12 ------------------------------
# rmse : 0.0007220353231804901
# mae : 0.00038784568433447423
# R² : 0.9835143370958548
# -------------------------- 13 --------------------------
# 1754
# (7017, 6)
# (1754, 6)
# trainX.Shape:---- (7016, 1, 6)
# trainY.shape:---- (7016,)
# testX.shape:---- (1753, 1, 6)
# testY.shape:---- (1753,)
# ---------------------------- 13 ------------------------------
# rmse : 0.004667344362806853
# mae : 0.004216094976845545
# R² : -4.434278912918626
# CPU times: total: 39.2 s
# Wall time: 6.22 s

# %%
# WL(Water Level(m)) For IMF1-IMF13-R True Value
finally_y_true
# Out:
# [array([ 0.01935259,  0.02213772, -0.00627413, ...,  0.00657959,
#         -0.00548436,  0.04189374]),
#  array([ 0.00602579,  0.00311664, -0.00040043, ..., -0.00353838,
#          0.00971867,  0.03905641]),
#  array([0.07479785, 0.11011702, 0.10247981, ..., 0.06663579, 0.10985025,
#         0.12167445]),
#  array([ 0.05415091,  0.07486614,  0.07087559, ..., -0.03213811,
#         -0.0074835 ,  0.00763638]),
#  array([-0.08635675, -0.08601982, -0.08061906, ..., -0.06512362,
#         -0.04250088, -0.01775367]),
#  array([-0.00324769, -0.00368721, -0.00365793, ...,  0.00950843,
#          0.00878657,  0.00752471]),
#  array([0.00526768, 0.00521012, 0.00509492, ..., 0.01224018, 0.01220006,
#         0.01198972]),
#  array([ 0.00919664,  0.00864159,  0.00808506, ..., -0.00338509,
#         -0.00330145, -0.00323046]),
#  array([0.01159903, 0.01157905, 0.01155336, ..., 0.00690326, 0.00689075,
#         0.00687973]),
#  array([-3.54945373e-05, -4.83964168e-05, -6.17971893e-05, ...,
#         -6.03997249e-03, -6.01749292e-03, -5.99570097e-03]),
#  array([0.00394529, 0.00386792, 0.00379045, ..., 0.01809421, 0.01807585,
#         0.01805741]),
#  array([ 0.01842047,  0.01832746,  0.01823433, ..., -0.02116324,
#         -0.02115159, -0.02114005]),
#  array([0.0474772 , 0.04747861, 0.04747998, ..., 0.03006073, 0.03004923,
#         0.03003775]),
#  array([0.37840647, 0.37841316, 0.37841985, ..., 0.38536623, 0.38536792,
#         0.3853696 ])]

# %%
finally_ytrue_r = np.array(finally_y_true)

# %%
finally_ytrue_r
# Out:
# array([[ 0.01935259,  0.02213772, -0.00627413, ...,  0.00657959,
#         -0.00548436,  0.04189374],
#        [ 0.00602579,  0.00311664, -0.00040043, ..., -0.00353838,
#          0.00971867,  0.03905641],
#        [ 0.07479785,  0.11011702,  0.10247981, ...,  0.06663579,
#          0.10985025,  0.12167445],
#        ...,
#        [ 0.01842047,  0.01832746,  0.01823433, ..., -0.02116324,
#         -0.02115159, -0.02114005],
#        [ 0.0474772 ,  0.04747861,  0.04747998, ...,  0.03006073,
#          0.03004923,  0.03003775],
#        [ 0.37840647,  0.37841316,  0.37841985, ...,  0.38536623,
#          0.38536792,  0.3853696 ]])

# %%
ALL_Factor_ReIMFS_Yture_Result = np.transpose(finally_ytrue_r)
ALL_Factor_ReIMFS_Yture_Result
# Out:
# array([[ 0.01935259,  0.00602579,  0.07479785, ...,  0.01842047,
#          0.0474772 ,  0.37840647],
#        [ 0.02213772,  0.00311664,  0.11011702, ...,  0.01832746,
#          0.04747861,  0.37841316],
#        [-0.00627413, -0.00040043,  0.10247981, ...,  0.01823433,
#          0.04747998,  0.37841985],
#        ...,
#        [ 0.00657959, -0.00353838,  0.06663579, ..., -0.02116324,
#          0.03006073,  0.38536623],
#        [-0.00548436,  0.00971867,  0.10985025, ..., -0.02115159,
#          0.03004923,  0.38536792],
#        [ 0.04189374,  0.03905641,  0.12167445, ..., -0.02114005,
#          0.03003775,  0.3853696 ]])

# %%
finally_column_names = ["IMF1", "IMF2", "IMF3", "IMF4", "IMF5", "IMF6", "IMF7", "IMF8", "IMF9", "IMF10", "IMF11",
                        "IMF12", "IMF13", "Residual"]
all_factor_ceemdan_true = pd.DataFrame(ALL_Factor_ReIMFS_Yture_Result, columns=finally_column_names)
all_factor_ceemdan_true
# Out:
#           IMF1      IMF2      IMF3      IMF4      IMF5      IMF6      IMF7  \
# 0     0.019353  0.006026  0.074798  0.054151 -0.086357 -0.003248  0.005268
# 1     0.022138  0.003117  0.110117  0.074866 -0.086020 -0.003687  0.005210
# 2    -0.006274 -0.000400  0.102480  0.070876 -0.080619 -0.003658  0.005095
# 3     0.011814 -0.000747  0.060177  0.046883 -0.070521 -0.003263  0.004921
# 4    -0.007088  0.000671  0.005044  0.011831 -0.056453 -0.002656  0.004688
# ...        ...       ...       ...       ...       ...       ...       ...
# 1748 -0.018142 -0.005367 -0.035317 -0.096675 -0.101490  0.009539  0.011803
# 1749  0.011666 -0.004371  0.007326 -0.064327 -0.084881  0.009733  0.012106
# 1750  0.006580 -0.003538  0.066636 -0.032138 -0.065124  0.009508  0.012240
# 1751 -0.005484  0.009719  0.109850 -0.007484 -0.042501  0.008787  0.012200
# 1752  0.041894  0.039056  0.121674  0.007636 -0.017754  0.007525  0.011990
#
#           IMF8      IMF9     IMF10     IMF11     IMF12     IMF13  Residual
# 0     0.009197  0.011599 -0.000035  0.003945  0.018420  0.047477  0.378406
# 1     0.008642  0.011579 -0.000048  0.003868  0.018327  0.047479  0.378413
# 2     0.008085  0.011553 -0.000062  0.003790  0.018234  0.047480  0.378420
# 3     0.007528  0.011522 -0.000076  0.003713  0.018141  0.047481  0.378427
# 4     0.006970  0.011484 -0.000090  0.003635  0.018048  0.047483  0.378433
# ...        ...       ...       ...       ...       ...       ...       ...
# 1748 -0.003586  0.006932 -0.006087  0.018131 -0.021187  0.030084  0.385363
# 1749 -0.003481  0.006917 -0.006063  0.018112 -0.021175  0.030072  0.385365
# 1750 -0.003385  0.006903 -0.006040  0.018094 -0.021163  0.030061  0.385366
# 1751 -0.003301  0.006891 -0.006017  0.018076 -0.021152  0.030049  0.385368
# 1752 -0.003230  0.006880 -0.005996  0.018057 -0.021140  0.030038  0.385370
#
# [1753 rows x 14 columns]

# %%
# 保存为CSV文件
all_factor_ceemdan_true.to_csv("CEEMDAN_RF_ALL_Factor_KAHUKUI_True.csv", index=False)

# %%
# WL(Water Level(m)) IMF1-IMF13-R Prediction Value
finally_rsult
# Out:
# [array([ 0.00265423,  0.00066004, -0.00190807, ..., -0.00840225,
#         -0.00145758, -0.00196376]),
#  array([ 0.00114717,  0.00396264,  0.0010885 , ..., -0.00201254,
#         -0.00215089,  0.0059634 ]),
#  array([-0.00859804,  0.06582823,  0.09566527, ...,  0.00978348,
#          0.05054258,  0.11190045]),
#  array([ 0.01344022,  0.07248386,  0.08382914, ..., -0.04715855,
#         -0.04703403, -0.01900804]),
#  array([-0.07505375, -0.08337314, -0.07950598, ..., -0.08094621,
#         -0.04906752, -0.02778506]),
#  array([-0.00211946, -0.00299826, -0.00383985, ...,  0.00984911,
#          0.00970876,  0.00846074]),
#  array([0.00518582, 0.00519522, 0.00523106, ..., 0.0118009 , 0.01179582,
#         0.01177283]),
#  array([ 0.00967095,  0.00912282,  0.00850553, ..., -0.00321924,
#         -0.00326129, -0.00322598]),
#  array([0.01165216, 0.01165642, 0.01166137, ..., 0.0066803 , 0.00667084,
#         0.00667084]),
#  array([-4.13482286e-05, -4.79198594e-05, -7.78923884e-05, ...,
#         -6.11281328e-03, -6.10587004e-03, -6.04184272e-03]),
#  array([0.00403817, 0.00395546, 0.00389795, ..., 0.0181057 , 0.01809452,
#         0.01806868]),
#  array([ 0.01852453,  0.01841751,  0.01834091, ..., -0.02118623,
#         -0.0211656 , -0.02116075]),
#  array([0.04747205, 0.04747205, 0.04747205, ..., 0.0300668 , 0.03006019,
#         0.03005147]),
#  array([0.37838297, 0.37838297, 0.37838297, ..., 0.37838297, 0.37838297,
#         0.37838297])]

# %%
finally_r = np.array(finally_rsult)
finally_r
# Out:
# array([[ 0.00265423,  0.00066004, -0.00190807, ..., -0.00840225,
#         -0.00145758, -0.00196376],
#        [ 0.00114717,  0.00396264,  0.0010885 , ..., -0.00201254,
#         -0.00215089,  0.0059634 ],
#        [-0.00859804,  0.06582823,  0.09566527, ...,  0.00978348,
#          0.05054258,  0.11190045],
#        ...,
#        [ 0.01852453,  0.01841751,  0.01834091, ..., -0.02118623,
#         -0.0211656 , -0.02116075],
#        [ 0.04747205,  0.04747205,  0.04747205, ...,  0.0300668 ,
#          0.03006019,  0.03005147],
#        [ 0.37838297,  0.37838297,  0.37838297, ...,  0.37838297,
#          0.37838297,  0.37838297]])

# %%
ALL_Factor_ReIMFS_Result = np.transpose(finally_r)
ALL_Factor_ReIMFS_Result
# Out:
# array([[ 0.00265423,  0.00114717, -0.00859804, ...,  0.01852453,
#          0.04747205,  0.37838297],
#        [ 0.00066004,  0.00396264,  0.06582823, ...,  0.01841751,
#          0.04747205,  0.37838297],
#        [-0.00190807,  0.0010885 ,  0.09566527, ...,  0.01834091,
#          0.04747205,  0.37838297],
#        ...,
#        [-0.00840225, -0.00201254,  0.00978348, ..., -0.02118623,
#          0.0300668 ,  0.37838297],
#        [-0.00145758, -0.00215089,  0.05054258, ..., -0.0211656 ,
#          0.03006019,  0.37838297],
#        [-0.00196376,  0.0059634 ,  0.11190045, ..., -0.02116075,
#          0.03005147,  0.37838297]])

# %%
finally_column_names = ["IMF1", "IMF2", "IMF3", "IMF4", "IMF5", "IMF6", "IMF7", "IMF8", "IMF9", "IMF10", "IMF11",
                        "IMF12", "IMF13", "Residual"]
all_factor_ceemdan_prediction = pd.DataFrame(ALL_Factor_ReIMFS_Result, columns=finally_column_names)
all_factor_ceemdan_prediction
# Out:
#           IMF1      IMF2      IMF3      IMF4      IMF5      IMF6      IMF7  \
# 0     0.002654  0.001147 -0.008598  0.013440 -0.075054 -0.002119  0.005186
# 1     0.000660  0.003963  0.065828  0.072484 -0.083373 -0.002998  0.005195
# 2    -0.001908  0.001088  0.095665  0.083829 -0.079506 -0.003840  0.005231
# 3     0.001432  0.000942  0.099733  0.088627 -0.078180 -0.003802  0.005110
# 4    -0.002088 -0.000215  0.090951  0.043210 -0.052956 -0.003280  0.005238
# ...        ...       ...       ...       ...       ...       ...       ...
# 1748 -0.003034 -0.000414 -0.061557 -0.138246 -0.099720  0.008928  0.010630
# 1749  0.000812 -0.002665 -0.019492 -0.082576 -0.087087  0.009978  0.011902
# 1750 -0.008402 -0.002013  0.009783 -0.047159 -0.080946  0.009849  0.011801
# 1751 -0.001458 -0.002151  0.050543 -0.047034 -0.049068  0.009709  0.011796
# 1752 -0.001964  0.005963  0.111900 -0.019008 -0.027785  0.008461  0.011773
#
#           IMF8      IMF9     IMF10     IMF11     IMF12     IMF13  Residual
# 0     0.009671  0.011652 -0.000041  0.004038  0.018525  0.047472  0.378383
# 1     0.009123  0.011656 -0.000048  0.003955  0.018418  0.047472  0.378383
# 2     0.008506  0.011661 -0.000078  0.003898  0.018341  0.047472  0.378383
# 3     0.007989  0.011649 -0.000071  0.003816  0.018263  0.047472  0.378383
# 4     0.007368  0.011657 -0.000082  0.003745  0.018145  0.047472  0.378383
# ...        ...       ...       ...       ...       ...       ...       ...
# 1748 -0.003543  0.006803 -0.006142  0.018143 -0.021194  0.030090  0.378383
# 1749 -0.003519  0.006763 -0.006124  0.018128 -0.021189  0.030088  0.378383
# 1750 -0.003219  0.006680 -0.006113  0.018106 -0.021186  0.030067  0.378383
# 1751 -0.003261  0.006671 -0.006106  0.018095 -0.021166  0.030060  0.378383
# 1752 -0.003226  0.006671 -0.006042  0.018069 -0.021161  0.030051  0.378383
#
# [1753 rows x 14 columns]

# %%
# # 保存为CSV文件
all_factor_ceemdan_prediction.to_csv("CEEMDAN_RF_ALL_Factor_KAHUKUI_Pred.csv",
                                     index=False)

# %%
df = pd.read_csv('CEEMDAN_RF_ALL_Factor_KAHUKUI_Pred.csv')
df = df[['Pred']]
df
# Out:
#           Pred
# 0     0.406356
# 1     0.530718
# 2     0.568743
# 3     0.581362
# 4     0.547548
# ...        ...
# 1748  0.119128
# 1749  0.233402
# 1750  0.295631
# 1751  0.375013
# 1752  0.492086
#
# [1753 rows x 1 columns]

# %%
### 验证最终结果

origin = pd.read_csv('../Data/NOAA/All Station/KAHUKUI Station.csv')
y_true = origin['Water Level(m)']
#数据集划分
# test_split = round(len(y_true) * 0.20)
# print(test_split)
test_split = round(len(y_true) * 0.20)
print(test_split)


def splitData(var, per_test):
    num_test = int(len(var) * per_test)
    train_size = int(len(var) - num_test)
    train_data = var[0:train_size]
    test_data = var[train_size:train_size + num_test]
    return train_data, test_data


df_training, df_testing = splitData(y_true, 0.2)
print(df_training.shape)
print(df_testing.shape)

print("df_testing.shape", len(df_testing))


def createXY(dataset, n_past):
    data_X = []
    data_Y = []
    for i in range(n_past, len(dataset)):
        data_X.append(dataset[i - n_past:i])
        data_Y.append(dataset[i:i + 1])

    return np.array(data_X), np.array(data_Y)


# trainX, trainY = createXY(df_training, 1)
testX, testY = createXY(df_testing, 1)

# print('trainX.Shape:----', trainX.shape)
# print('trainY.shape:----', trainY.shape)
print('testX.shape:----', testX.shape)
print('testY.shape:----', testY.shape)
# Out:
# 1754
# (7018,)
# (1754,)
# df_testing.shape 1754
# testX.shape:---- (1753, 1)
# testY.shape:---- (1753, 1)

# %%
testY
# Out:
# array([[0.539],
#        [0.594],
#        [0.555],
#        ...,
#        [0.404],
#        [0.495],
#        [0.622]])

# %%
y_true = testY[0:1752]
pred = df[1:1753]

# %%
y_true
# Out:
# array([[0.539],
#        [0.594],
#        [0.555],
#        ...,
#        [0.297],
#        [0.404],
#        [0.495]])

# %%
pred
# Out:
#           Pred
# 1     0.530718
# 2     0.568743
# 3     0.581362
# 4     0.547548
# 5     0.403997
# ...        ...
# 1748  0.119128
# 1749  0.233402
# 1750  0.295631
# 1751  0.375013
# 1752  0.492086
#
# [1752 rows x 1 columns]

# %%
def nRMSE(rmse,y_true):
    return rmse / (max(y_true) - min(y_true))

plt.plot(y_true, color='red', label='Real Value')
plt.plot(pred, color='blue', label='Pred Value')
plt.title('Prediction SW_IN_F ')
plt.xlabel('Time')
plt.ylabel('Detail Value')
plt.legend()
# plt.savefig('../Images/SW_IN_F_Train_'+'n_past='+'{}'.format((trainX[1].shape)[0])+'_epochs={}'.format((grid_search.best_params_)['epochs'])+'.png',dpi=600)
plt.show()
# y_true_data = pd.DataFrame(y)
# y_true_data.to_csv('../ResultAnaAndProcess/Result/All Features/RF/37390_300/' + 'RF_{}'.format(site_name) + '_True' + '.csv',
#               index=False)
# pred_data = pd.DataFrame(pred)
# pred_data.to_csv('../ResultAnaAndProcess/Result/All Features/RF/37390_300/' + 'RF_{}'.format(site_name) + '_Pre' + '.csv',
#              index=False)
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import r2_score as r2
nrmse = nRMSE(np.sqrt(mse(y_true, pred)),y_true)
print('MSE:', mse(y_true, pred))
print('MAE:', mae(y_true, pred))
print('R²:', r2(y_true, pred))
print('RMSE:', np.sqrt(mse(y_true, pred)))
print('nRMSE:', nRMSE(np.sqrt(mse(y_true, pred)),y_true))
# print('pred_finally:', pred)
# Out:
# MSE: 0.001588623048685495
# MAE: 0.031686984175799085
# R²: 0.9694884467853089
# RMSE: 0.039857534402989545
# nRMSE: [0.03165809]
