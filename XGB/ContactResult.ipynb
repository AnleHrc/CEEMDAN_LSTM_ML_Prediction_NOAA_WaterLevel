# %%
import pandas as pd
import os

# 创建一个空的数据框来存储合并后的数据
merged_data = pd.DataFrame()

# 指定文件夹路径
folder_path = '../XGB/'  # 将 "your_folder_path" 替换为包含这些文件的文件夹的实际路径

# 遍历文件夹中的每个文件
for filename in os.listdir(folder_path):
    if filename.endswith(".csv"):  # 确保只处理 CSV 文件
        file_path = os.path.join(folder_path, filename)
        print(file_path)
        # 读取 CSV 文件
        data = pd.read_csv(file_path)
        print(data)
        # 从文件名中提取站点名和月份
        print(filename.split(".")[0].split("_"))
        print(filename.split("cs")[2].split('.')[0])
        station_name = filename.split(".")[0].split("_")[0]
        month = filename.split("cs")[2].split('.')[0]
        data["Station"] = station_name
        data["Month"] = month

        # 合并数据到总数据框
        merged_data = pd.concat([merged_data, data])
# 打印合并后的数据
print(merged_data)
# 保存合并后的数据到新的 CSV 文件
output_path = "merged_data.csv"  # 指定输出文件的路径和文件名
merged_data.to_csv(output_path, index=False)
# Out:
# ../XGB/Burlington Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.738431
# 1   RMSE  0.398562
# 2    MAE  0.342395
# ['Burlington Station']
# 12
# ../XGB/Burlington Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.756926
# 1   RMSE  0.391728
# 2    MAE  0.346668
# ['Burlington Station']
# 3
# ../XGB/Burlington Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.739934
# 1   RMSE  0.411579
# 2    MAE  0.361923
# ['Burlington Station']
# 6
# ../XGB/Burlington Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.724111
# 1   RMSE  0.411739
# 2    MAE  0.360234
# ['Burlington Station']
# 9
# ../XGB/HONOLULU Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.837774
# 1   RMSE  0.081267
# 2    MAE  0.064807
# ['HONOLULU Station']
# 12
# ../XGB/HONOLULU Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.811315
# 1   RMSE  0.071505
# 2    MAE  0.058485
# ['HONOLULU Station']
# 3
# ../XGB/HONOLULU Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.866286
# 1   RMSE  0.070357
# 2    MAE  0.056243
# ['HONOLULU Station']
# 6
# ../XGB/HONOLULU Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.814628
# 1   RMSE  0.073602
# 2    MAE  0.060112
# ['HONOLULU Station']
# 9
# ../XGB/KAHUKUI Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.821806
# 1   RMSE  0.097693
# 2    MAE  0.077589
# ['KAHUKUI Station']
# 12
# ../XGB/KAHUKUI Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.784303
# 1   RMSE  0.095532
# 2    MAE  0.079137
# ['KAHUKUI Station']
# 3
# ../XGB/KAHUKUI Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.845762
# 1   RMSE  0.091731
# 2    MAE  0.074520
# ['KAHUKUI Station']
# 6
# ../XGB/KAHUKUI Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.780088
# 1   RMSE  0.096630
# 2    MAE  0.078547
# ['KAHUKUI Station']
# 9
# ../XGB/LaJolla Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.818765
# 1   RMSE  0.220774
# 2    MAE  0.182556
# ['LaJolla Station']
# 12
# ../XGB/LaJolla Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.808215
# 1   RMSE  0.215164
# 2    MAE  0.178650
# ['LaJolla Station']
# 3
# ../XGB/LaJolla Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.826653
# 1   RMSE  0.213636
# 2    MAE  0.176506
# ['LaJolla Station']
# 6
# ../XGB/LaJolla Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.741048
# 1   RMSE  0.243643
# 2    MAE  0.197327
# ['LaJolla Station']
# 9
# ../XGB/Nawiliwili Station.cs_metrics12.csv
#   Metric     Value
# 0     R2  0.850917
# 1   RMSE  0.076015
# 2    MAE  0.061386
# ['Nawiliwili Station']
# 12
# ../XGB/Nawiliwili Station.cs_metrics3.csv
#   Metric     Value
# 0     R2  0.825199
# 1   RMSE  0.069976
# 2    MAE  0.057454
# ['Nawiliwili Station']
# 3
# ../XGB/Nawiliwili Station.cs_metrics6.csv
#   Metric     Value
# 0     R2  0.871782
# 1   RMSE  0.071245
# 2    MAE  0.057664
# ['Nawiliwili Station']
# 6
# ../XGB/Nawiliwili Station.cs_metrics9.csv
#   Metric     Value
# 0     R2  0.815952
# 1   RMSE  0.074098
# 2    MAE  0.060110
# ['Nawiliwili Station']
# 9
#   Metric     Value             Station Month
# 0     R2  0.738431  Burlington Station    12
# 1   RMSE  0.398562  Burlington Station    12
# 2    MAE  0.342395  Burlington Station    12
# 0     R2  0.756926  Burlington Station     3
# 1   RMSE  0.391728  Burlington Station     3
# 2    MAE  0.346668  Burlington Station     3
# 0     R2  0.739934  Burlington Station     6
# 1   RMSE  0.411579  Burlington Station     6
# 2    MAE  0.361923  Burlington Station     6
# 0     R2  0.724111  Burlington Station     9
# 1   RMSE  0.411739  Burlington Station     9
# 2    MAE  0.360234  Burlington Station     9
# 0     R2  0.837774    HONOLULU Station    12
# 1   RMSE  0.081267    HONOLULU Station    12
# 2    MAE  0.064807    HONOLULU Station    12
# 0     R2  0.811315    HONOLULU Station     3
# 1   RMSE  0.071505    HONOLULU Station     3
# 2    MAE  0.058485    HONOLULU Station     3
# 0     R2  0.866286    HONOLULU Station     6
# 1   RMSE  0.070357    HONOLULU Station     6
# 2    MAE  0.056243    HONOLULU Station     6
# 0     R2  0.814628    HONOLULU Station     9
# 1   RMSE  0.073602    HONOLULU Station     9
# 2    MAE  0.060112    HONOLULU Station     9
# 0     R2  0.821806     KAHUKUI Station    12
# 1   RMSE  0.097693     KAHUKUI Station    12
# 2    MAE  0.077589     KAHUKUI Station    12
# 0     R2  0.784303     KAHUKUI Station     3
# 1   RMSE  0.095532     KAHUKUI Station     3
# 2    MAE  0.079137     KAHUKUI Station     3
# 0     R2  0.845762     KAHUKUI Station     6
# 1   RMSE  0.091731     KAHUKUI Station     6
# 2    MAE  0.074520     KAHUKUI Station     6
# 0     R2  0.780088     KAHUKUI Station     9
# 1   RMSE  0.096630     KAHUKUI Station     9
# 2    MAE  0.078547     KAHUKUI Station     9
# 0     R2  0.818765     LaJolla Station    12
# 1   RMSE  0.220774     LaJolla Station    12
# 2    MAE  0.182556     LaJolla Station    12
# 0     R2  0.808215     LaJolla Station     3
# 1   RMSE  0.215164     LaJolla Station     3
# 2    MAE  0.178650     LaJolla Station     3
# 0     R2  0.826653     LaJolla Station     6
# 1   RMSE  0.213636     LaJolla Station     6
# 2    MAE  0.176506     LaJolla Station     6
# 0     R2  0.741048     LaJolla Station     9
# 1   RMSE  0.243643     LaJolla Station     9
# 2    MAE  0.197327     LaJolla Station     9
# 0     R2  0.850917  Nawiliwili Station    12
# 1   RMSE  0.076015  Nawiliwili Station    12
# 2    MAE  0.061386  Nawiliwili Station    12
# 0     R2  0.825199  Nawiliwili Station     3
# 1   RMSE  0.069976  Nawiliwili Station     3
# 2    MAE  0.057454  Nawiliwili Station     3
# 0     R2  0.871782  Nawiliwili Station     6
# 1   RMSE  0.071245  Nawiliwili Station     6
# 2    MAE  0.057664  Nawiliwili Station     6
# 0     R2  0.815952  Nawiliwili Station     9
# 1   RMSE  0.074098  Nawiliwili Station     9
# 2    MAE  0.060110  Nawiliwili Station     9
